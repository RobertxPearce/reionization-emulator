# %% [markdown]
# # Emulator Data Visualization Notebook

# %%
# %matplotlib inline
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
DATA_PATH = "../data/processed/emulator_dataset_v1.npz"
data = np.load(DATA_PATH, allow_pickle=True)

# %% [markdown]
# ## Data Structure

# %%
print("Keys in npz:", data.files)

X = data["X"]
Y = data["Y"]
ell = data["ell"]
sim_ids = data["sim_ids"]

print("X Shape:", X.shape)
print("Y Shape:", Y.shape)
print("ell Shape:", ell.shape)
# Out:
# Keys in npz: ['X', 'Y', 'ell', 'sim_ids']
# X Shape: (100, 4)
# Y Shape: (100, 15)
# ell Shape: (15,)
